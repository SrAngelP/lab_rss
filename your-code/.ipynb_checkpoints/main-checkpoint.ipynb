# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
doc = feedparser.parse(url)
doc.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
list(doc.keys())
# Out:
# ['bozo',
#  'entries',
#  'feed',
#  'headers',
#  'updated',
#  'updated_parsed',
#  'href',
#  'status',
#  'encoding',
#  'version',
#  'namespaces']

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
list((doc['feed']).keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'subtitle',
#  'subtitle_detail',
#  'updated',
#  'updated_parsed',
#  'language',
#  'sy_updateperiod',
#  'sy_updatefrequency',
#  'generator_detail',
#  'generator']

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
title = doc['feed']['title']
subtitle = doc['feed']['subtitle']
author = doc['feed']['generator']
link = doc['feed']['link']

print('\n',title,'\n',subtitle, '\n', author, '\n', link)
# Out:
#  Radar
#  Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
#  https://wordpress.org/?v=5.3.14
#  https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(doc['entries'])
# Out:
# 15

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
list((doc['entries'][0]).keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'comments',
#  'published',
#  'published_parsed',
#  'authors',
#  'author',
#  'author_detail',
#  'tags',
#  'id',
#  'guidislink',
#  'summary',
#  'summary_detail',
#  'content',
#  'wfw_commentrss',
#  'slash_comments']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [x['title'] for x in doc['entries']]
titles
# Out:
# ['Radar Trends to Watch: November 2022',
#  'What We Learned Auditing Sophisticated AI for Bias',
#  'The Collaborative Metaverse',
#  'What Is Hyperautomation?',
#  'Radar Trends to Watch: October 2022',
#  'The Problem with Intelligence',
#  'Radar Trends to Watch: September 2022',
#  'Ad Networks and Content Marketing',
#  'On Technique',
#  'Scaling False Peaks',
#  'The Metaverse Is Not a Place',
#  'Radar Trends to Watch: August 2022',
#  'SQL: The Universal Solvent for REST APIs',
#  'Artificial Creativity?',
#  'Radar Trends to Watch: July 2022']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
radar_trends = [x for x in titles if 'Radar Trends to Watch' in x]
percentage = (len(radar_trends)*100)/len(titles)
percentage
# Out:
# 33.333333333333336

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df_entries = pd.DataFrame(doc['entries'])
df_entries
# Out:
#                                                 title  \
# 0                Radar Trends to Watch: November 2022
# 1   What We Learned Auditing Sophisticated AI for ...
# 2                         The Collaborative Metaverse
# 3                            What Is Hyperautomation?
# 4                 Radar Trends to Watch: October 2022
# 5                       The Problem with Intelligence
# 6               Radar Trends to Watch: September 2022
# 7                   Ad Networks and Content Marketing
# 8                                        On Technique
# 9                                 Scaling False Peaks
# 10                       The Metaverse Is Not a Place
# 11                 Radar Trends to Watch: August 2022
# 12           SQL: The Universal Solvent for REST APIs
# 13                             Artificial Creativity?
# 14                   Radar Trends to Watch: July 2022
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 0   https://www.oreilly.com/radar/radar-trends-to-...
# 1   https://www.oreilly.com/radar/what-we-learned-...
# 2   https://www.oreilly.com/radar/the-collaborativ...
# 3   https://www.oreilly.com/radar/what-is-hyperaut...
# 4   https://www.oreilly.com/radar/radar-trends-to-...
# 5   https://www.oreilly.com/radar/the-problem-with...
# 6   https://www.oreilly.com/radar/radar-trends-to-...
# 7   https://www.oreilly.com/radar/ad-networks-and-...
# 8         https://www.oreilly.com/radar/on-technique/
# 9   https://www.oreilly.com/radar/scaling-false-pe...
# 10  https://www.oreilly.com/radar/the-metaverse-is...
# 11  https://www.oreilly.com/radar/radar-trends-to-...
# 12  https://www.oreilly.com/radar/sql-the-universa...
# 13  https://www.oreilly.com/radar/artificial-creat...
# 14  https://www.oreilly.com/radar/radar-trends-to-...
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/radar-trends-to-...
# 1   https://www.oreilly.com/radar/what-we-learned-...
# 2   https://www.oreilly.com/radar/the-collaborativ...
# 3   https://www.oreilly.com/radar/what-is-hyperaut...
# 4   https://www.oreilly.com/radar/radar-trends-to-...
# 5   https://www.oreilly.com/radar/the-problem-with...
# 6   https://www.oreilly.com/radar/radar-trends-to-...
# 7   https://www.oreilly.com/radar/ad-networks-and-...
# 8   https://www.oreilly.com/radar/on-technique/#re...
# 9   https://www.oreilly.com/radar/scaling-false-pe...
# 10  https://www.oreilly.com/radar/the-metaverse-is...
# 11  https://www.oreilly.com/radar/radar-trends-to-...
# 12  https://www.oreilly.com/radar/sql-the-universa...
# 13  https://www.oreilly.com/radar/artificial-creat...
# 14  https://www.oreilly.com/radar/radar-trends-to-...
#
#                           published                       published_parsed  \
# 0   Tue, 01 Nov 2022 11:15:57 +0000   (2022, 11, 1, 11, 15, 57, 1, 305, 0)
# 1   Tue, 18 Oct 2022 11:14:23 +0000  (2022, 10, 18, 11, 14, 23, 1, 291, 0)
# 2   Wed, 12 Oct 2022 20:01:45 +0000   (2022, 10, 12, 20, 1, 45, 2, 285, 0)
# 3   Tue, 11 Oct 2022 10:59:21 +0000  (2022, 10, 11, 10, 59, 21, 1, 284, 0)
# 4   Tue, 04 Oct 2022 11:15:42 +0000   (2022, 10, 4, 11, 15, 42, 1, 277, 0)
# 5   Tue, 13 Sep 2022 11:21:40 +0000   (2022, 9, 13, 11, 21, 40, 1, 256, 0)
# 6   Tue, 06 Sep 2022 11:21:09 +0000     (2022, 9, 6, 11, 21, 9, 1, 249, 0)
# 7   Tue, 16 Aug 2022 11:21:21 +0000   (2022, 8, 16, 11, 21, 21, 1, 228, 0)
# 8   Tue, 09 Aug 2022 11:12:22 +0000    (2022, 8, 9, 11, 12, 22, 1, 221, 0)
# 9   Thu, 04 Aug 2022 11:12:44 +0000    (2022, 8, 4, 11, 12, 44, 3, 216, 0)
# 10  Tue, 02 Aug 2022 18:38:46 +0000    (2022, 8, 2, 18, 38, 46, 1, 214, 0)
# 11  Tue, 02 Aug 2022 11:18:24 +0000    (2022, 8, 2, 11, 18, 24, 1, 214, 0)
# 12  Tue, 19 Jul 2022 11:16:39 +0000   (2022, 7, 19, 11, 16, 39, 1, 200, 0)
# 13  Tue, 12 Jul 2022 13:24:16 +0000   (2022, 7, 12, 13, 24, 16, 1, 193, 0)
# 14  Tue, 05 Jul 2022 11:09:04 +0000      (2022, 7, 5, 11, 9, 4, 1, 186, 0)
#
#                         authors         author              author_detail  \
# 0   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 1    [{'name': 'Patrick Hall'}]   Patrick Hall   {'name': 'Patrick Hall'}
# 2   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 3   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 4   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 5   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 6   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 7      [{'name': 'Q McCallum'}]     Q McCallum     {'name': 'Q McCallum'}
# 8   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 9   [{'name': 'Kevlin Henney'}]  Kevlin Henney  {'name': 'Kevlin Henney'}
# 10   [{'name': 'Tim O’Reilly'}]   Tim O’Reilly   {'name': 'Tim O’Reilly'}
# 11  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 12      [{'name': 'Jon Udell'}]      Jon Udell      {'name': 'Jon Udell'}
# 13  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 14  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
#
#                                                  tags  \
# 0   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 1   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 2   [{'term': 'Metaverse', 'scheme': None, 'label'...
# 3   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 4   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 5   [{'term': 'Artificial Intelligence', 'scheme':...
# 6   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 7   [{'term': 'Operations', 'scheme': None, 'label...
# 8   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 9   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 10  [{'term': 'Metaverse', 'scheme': None, 'label'...
# 11  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 12  [{'term': 'Data', 'scheme': None, 'label': Non...
# 13  [{'term': 'Artificial Intelligence', 'scheme':...
# 14  [{'term': 'Radar Trends', 'scheme': None, 'lab...
#
#                                         id  guidislink  \
# 0   https://www.oreilly.com/radar/?p=14760       False
# 1   https://www.oreilly.com/radar/?p=14754       False
# 2   https://www.oreilly.com/radar/?p=14750       False
# 3   https://www.oreilly.com/radar/?p=14733       False
# 4   https://www.oreilly.com/radar/?p=14726       False
# 5   https://www.oreilly.com/radar/?p=14718       False
# 6   https://www.oreilly.com/radar/?p=14700       False
# 7   https://www.oreilly.com/radar/?p=14688       False
# 8   https://www.oreilly.com/radar/?p=14669       False
# 9   https://www.oreilly.com/radar/?p=14661       False
# 10  https://www.oreilly.com/radar/?p=14641       False
# 11  https://www.oreilly.com/radar/?p=14631       False
# 12  https://www.oreilly.com/radar/?p=14612       False
# 13  https://www.oreilly.com/radar/?p=14604       False
# 14  https://www.oreilly.com/radar/?p=14591       False
#
#                                               summary  \
# 0   Maintaining a separate category for AI is gett...
# 1   A recently passed law in New York City require...
# 2   We want to congratulate Dylan Field on his sta...
# 3   Gartner has anointed “Hyperautomation” one of ...
# 4   September was a busy month. In addition to con...
# 5   Projects like OpenAI’s DALL-E and DeepMind’s G...
# 6   It’s hardly news to talk about the AI developm...
# 7   In a recent Radar piece, I explored N-sided ma...
# 8   In a previous article, I wrote about how model...
# 9   Humans are notoriously poor at judging distanc...
# 10  The metaphors we use to describe new technolog...
# 11  The large model train keeps rolling on. This m...
# 12  Data scientists working in Python or R typical...
# 13  There’s a puzzling disconnect in the many arti...
# 14  This month, large models are even more in the ...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments
# 0   https://www.oreilly.com/radar/radar-trends-to-...              0
# 1   https://www.oreilly.com/radar/what-we-learned-...              0
# 2   https://www.oreilly.com/radar/the-collaborativ...              0
# 3   https://www.oreilly.com/radar/what-is-hyperaut...              0
# 4   https://www.oreilly.com/radar/radar-trends-to-...              0
# 5   https://www.oreilly.com/radar/the-problem-with...              0
# 6   https://www.oreilly.com/radar/radar-trends-to-...              0
# 7   https://www.oreilly.com/radar/ad-networks-and-...              0
# 8    https://www.oreilly.com/radar/on-technique/feed/              0
# 9   https://www.oreilly.com/radar/scaling-false-pe...              0
# 10  https://www.oreilly.com/radar/the-metaverse-is...              0
# 11  https://www.oreilly.com/radar/radar-trends-to-...              0
# 12  https://www.oreilly.com/radar/sql-the-universa...              0
# 13  https://www.oreilly.com/radar/artificial-creat...              0
# 14  https://www.oreilly.com/radar/radar-trends-to-...              0

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df2 = df_entries.groupby(['author'])['authors'].count()
df2.sort_values(ascending=False)
# Out:
# author
# Mike Loukides    10
# Jon Udell         1
# Kevlin Henney     1
# Patrick Hall      1
# Q McCallum        1
# Tim O’Reilly      1
# Name: authors, dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
len_title = ([len(x) for x in titles])
len_title

df_entries['len_title'] = len_title

df_entries.sort_values('len_title', ascending=False)
# Out:
#                                                 title  \
# 1   What We Learned Auditing Sophisticated AI for ...
# 12           SQL: The Universal Solvent for REST APIs
# 6               Radar Trends to Watch: September 2022
# 0                Radar Trends to Watch: November 2022
# 4                 Radar Trends to Watch: October 2022
# 11                 Radar Trends to Watch: August 2022
# 7                   Ad Networks and Content Marketing
# 14                   Radar Trends to Watch: July 2022
# 5                       The Problem with Intelligence
# 10                       The Metaverse Is Not a Place
# 2                         The Collaborative Metaverse
# 3                            What Is Hyperautomation?
# 13                             Artificial Creativity?
# 9                                 Scaling False Peaks
# 8                                        On Technique
#
#                                          title_detail  \
# 1   {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 0   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 1   https://www.oreilly.com/radar/what-we-learned-...
# 12  https://www.oreilly.com/radar/sql-the-universa...
# 6   https://www.oreilly.com/radar/radar-trends-to-...
# 0   https://www.oreilly.com/radar/radar-trends-to-...
# 4   https://www.oreilly.com/radar/radar-trends-to-...
# 11  https://www.oreilly.com/radar/radar-trends-to-...
# 7   https://www.oreilly.com/radar/ad-networks-and-...
# 14  https://www.oreilly.com/radar/radar-trends-to-...
# 5   https://www.oreilly.com/radar/the-problem-with...
# 10  https://www.oreilly.com/radar/the-metaverse-is...
# 2   https://www.oreilly.com/radar/the-collaborativ...
# 3   https://www.oreilly.com/radar/what-is-hyperaut...
# 13  https://www.oreilly.com/radar/artificial-creat...
# 9   https://www.oreilly.com/radar/scaling-false-pe...
# 8         https://www.oreilly.com/radar/on-technique/
#
#                                              comments  \
# 1   https://www.oreilly.com/radar/what-we-learned-...
# 12  https://www.oreilly.com/radar/sql-the-universa...
# 6   https://www.oreilly.com/radar/radar-trends-to-...
# 0   https://www.oreilly.com/radar/radar-trends-to-...
# 4   https://www.oreilly.com/radar/radar-trends-to-...
# 11  https://www.oreilly.com/radar/radar-trends-to-...
# 7   https://www.oreilly.com/radar/ad-networks-and-...
# 14  https://www.oreilly.com/radar/radar-trends-to-...
# 5   https://www.oreilly.com/radar/the-problem-with...
# 10  https://www.oreilly.com/radar/the-metaverse-is...
# 2   https://www.oreilly.com/radar/the-collaborativ...
# 3   https://www.oreilly.com/radar/what-is-hyperaut...
# 13  https://www.oreilly.com/radar/artificial-creat...
# 9   https://www.oreilly.com/radar/scaling-false-pe...
# 8   https://www.oreilly.com/radar/on-technique/#re...
#
#                           published                       published_parsed  \
# 1   Tue, 18 Oct 2022 11:14:23 +0000  (2022, 10, 18, 11, 14, 23, 1, 291, 0)
# 12  Tue, 19 Jul 2022 11:16:39 +0000   (2022, 7, 19, 11, 16, 39, 1, 200, 0)
# 6   Tue, 06 Sep 2022 11:21:09 +0000     (2022, 9, 6, 11, 21, 9, 1, 249, 0)
# 0   Tue, 01 Nov 2022 11:15:57 +0000   (2022, 11, 1, 11, 15, 57, 1, 305, 0)
# 4   Tue, 04 Oct 2022 11:15:42 +0000   (2022, 10, 4, 11, 15, 42, 1, 277, 0)
# 11  Tue, 02 Aug 2022 11:18:24 +0000    (2022, 8, 2, 11, 18, 24, 1, 214, 0)
# 7   Tue, 16 Aug 2022 11:21:21 +0000   (2022, 8, 16, 11, 21, 21, 1, 228, 0)
# 14  Tue, 05 Jul 2022 11:09:04 +0000      (2022, 7, 5, 11, 9, 4, 1, 186, 0)
# 5   Tue, 13 Sep 2022 11:21:40 +0000   (2022, 9, 13, 11, 21, 40, 1, 256, 0)
# 10  Tue, 02 Aug 2022 18:38:46 +0000    (2022, 8, 2, 18, 38, 46, 1, 214, 0)
# 2   Wed, 12 Oct 2022 20:01:45 +0000   (2022, 10, 12, 20, 1, 45, 2, 285, 0)
# 3   Tue, 11 Oct 2022 10:59:21 +0000  (2022, 10, 11, 10, 59, 21, 1, 284, 0)
# 13  Tue, 12 Jul 2022 13:24:16 +0000   (2022, 7, 12, 13, 24, 16, 1, 193, 0)
# 9   Thu, 04 Aug 2022 11:12:44 +0000    (2022, 8, 4, 11, 12, 44, 3, 216, 0)
# 8   Tue, 09 Aug 2022 11:12:22 +0000    (2022, 8, 9, 11, 12, 22, 1, 221, 0)
#
#                         authors         author              author_detail  \
# 1    [{'name': 'Patrick Hall'}]   Patrick Hall   {'name': 'Patrick Hall'}
# 12      [{'name': 'Jon Udell'}]      Jon Udell      {'name': 'Jon Udell'}
# 6   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 0   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 4   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 11  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 7      [{'name': 'Q McCallum'}]     Q McCallum     {'name': 'Q McCallum'}
# 14  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 5   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 10   [{'name': 'Tim O’Reilly'}]   Tim O’Reilly   {'name': 'Tim O’Reilly'}
# 2   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 3   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 13  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 9   [{'name': 'Kevlin Henney'}]  Kevlin Henney  {'name': 'Kevlin Henney'}
# 8   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
#
#                                                  tags  \
# 1   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 12  [{'term': 'Data', 'scheme': None, 'label': Non...
# 6   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 0   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 4   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 11  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 7   [{'term': 'Operations', 'scheme': None, 'label...
# 14  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 5   [{'term': 'Artificial Intelligence', 'scheme':...
# 10  [{'term': 'Metaverse', 'scheme': None, 'label'...
# 2   [{'term': 'Metaverse', 'scheme': None, 'label'...
# 3   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 13  [{'term': 'Artificial Intelligence', 'scheme':...
# 9   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 8   [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
#                                         id  guidislink  \
# 1   https://www.oreilly.com/radar/?p=14754       False
# 12  https://www.oreilly.com/radar/?p=14612       False
# 6   https://www.oreilly.com/radar/?p=14700       False
# 0   https://www.oreilly.com/radar/?p=14760       False
# 4   https://www.oreilly.com/radar/?p=14726       False
# 11  https://www.oreilly.com/radar/?p=14631       False
# 7   https://www.oreilly.com/radar/?p=14688       False
# 14  https://www.oreilly.com/radar/?p=14591       False
# 5   https://www.oreilly.com/radar/?p=14718       False
# 10  https://www.oreilly.com/radar/?p=14641       False
# 2   https://www.oreilly.com/radar/?p=14750       False
# 3   https://www.oreilly.com/radar/?p=14733       False
# 13  https://www.oreilly.com/radar/?p=14604       False
# 9   https://www.oreilly.com/radar/?p=14661       False
# 8   https://www.oreilly.com/radar/?p=14669       False
#
#                                               summary  \
# 1   A recently passed law in New York City require...
# 12  Data scientists working in Python or R typical...
# 6   It’s hardly news to talk about the AI developm...
# 0   Maintaining a separate category for AI is gett...
# 4   September was a busy month. In addition to con...
# 11  The large model train keeps rolling on. This m...
# 7   In a recent Radar piece, I explored N-sided ma...
# 14  This month, large models are even more in the ...
# 5   Projects like OpenAI’s DALL-E and DeepMind’s G...
# 10  The metaphors we use to describe new technolog...
# 2   We want to congratulate Dylan Field on his sta...
# 3   Gartner has anointed “Hyperautomation” one of ...
# 13  There’s a puzzling disconnect in the many arti...
# 9   Humans are notoriously poor at judging distanc...
# 8   In a previous article, I wrote about how model...
#
#                                        summary_detail  \
# 1   {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 0   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 1   [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 0   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments  \
# 1   https://www.oreilly.com/radar/what-we-learned-...              0
# 12  https://www.oreilly.com/radar/sql-the-universa...              0
# 6   https://www.oreilly.com/radar/radar-trends-to-...              0
# 0   https://www.oreilly.com/radar/radar-trends-to-...              0
# 4   https://www.oreilly.com/radar/radar-trends-to-...              0
# 11  https://www.oreilly.com/radar/radar-trends-to-...              0
# 7   https://www.oreilly.com/radar/ad-networks-and-...              0
# 14  https://www.oreilly.com/radar/radar-trends-to-...              0
# 5   https://www.oreilly.com/radar/the-problem-with...              0
# 10  https://www.oreilly.com/radar/the-metaverse-is...              0
# 2   https://www.oreilly.com/radar/the-collaborativ...              0
# 3   https://www.oreilly.com/radar/what-is-hyperaut...              0
# 13  https://www.oreilly.com/radar/artificial-creat...              0
# 9   https://www.oreilly.com/radar/scaling-false-pe...              0
# 8    https://www.oreilly.com/radar/on-technique/feed/              0
#
#     len_title
# 1          50
# 12         40
# 6          37
# 0          36
# 4          35
# 11         34
# 7          33
# 14         32
# 5          29
# 10         28
# 2          27
# 3          24
# 13         22
# 9          19
# 8          12

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
[x['title'] for x in doc['entries'] if 'machine learning' in x['summary']]
# Out:
# ['Radar Trends to Watch: October 2022']
