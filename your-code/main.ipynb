# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
doc = feedparser.parse(url)
doc.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
list(doc.keys())
# Out:
# ['bozo',
#  'entries',
#  'feed',
#  'headers',
#  'updated',
#  'updated_parsed',
#  'href',
#  'status',
#  'encoding',
#  'version',
#  'namespaces']

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
list((doc['feed']).keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'subtitle',
#  'subtitle_detail',
#  'updated',
#  'updated_parsed',
#  'language',
#  'sy_updateperiod',
#  'sy_updatefrequency',
#  'generator_detail',
#  'generator']

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
title = doc['feed']['title']
subtitle = doc['feed']['subtitle']
author = doc['feed']['generator']
link = doc['feed']['link']

print('\n',title,'\n',subtitle, '\n', author, '\n', link)
# Out:
#  Radar
#  Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
#  https://wordpress.org/?v=5.3.14
#  https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(doc['entries'])
# Out:
# 15

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
list((doc['entries'][0]).keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'comments',
#  'published',
#  'published_parsed',
#  'authors',
#  'author',
#  'author_detail',
#  'tags',
#  'id',
#  'guidislink',
#  'summary',
#  'summary_detail',
#  'content',
#  'wfw_commentrss',
#  'slash_comments']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [x['title'] for x in doc['entries']]
titles
# Out:
# ['Formal Informal Languages',
#  'Radar Trends to Watch: November 2022',
#  'What We Learned Auditing Sophisticated AI for Bias',
#  'The Collaborative Metaverse',
#  'What Is Hyperautomation?',
#  'Radar Trends to Watch: October 2022',
#  'The Problem with Intelligence',
#  'Radar Trends to Watch: September 2022',
#  'Ad Networks and Content Marketing',
#  'On Technique',
#  'Scaling False Peaks',
#  'The Metaverse Is Not a Place',
#  'Radar Trends to Watch: August 2022',
#  'SQL: The Universal Solvent for REST APIs',
#  'Artificial Creativity?']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
radar_trends = [x for x in titles if 'Radar Trends to Watch' in x]
percentage = (len(radar_trends)*100)/len(titles)
percentage
# Out:
# 26.666666666666668

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df_entries = pd.DataFrame(doc['entries'])
df_entries
# Out:
#                                                 title  \
# 0                           Formal Informal Languages
# 1                Radar Trends to Watch: November 2022
# 2   What We Learned Auditing Sophisticated AI for ...
# 3                         The Collaborative Metaverse
# 4                            What Is Hyperautomation?
# 5                 Radar Trends to Watch: October 2022
# 6                       The Problem with Intelligence
# 7               Radar Trends to Watch: September 2022
# 8                   Ad Networks and Content Marketing
# 9                                        On Technique
# 10                                Scaling False Peaks
# 11                       The Metaverse Is Not a Place
# 12                 Radar Trends to Watch: August 2022
# 13           SQL: The Universal Solvent for REST APIs
# 14                             Artificial Creativity?
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 0   https://www.oreilly.com/radar/formal-informal-...
# 1   https://www.oreilly.com/radar/radar-trends-to-...
# 2   https://www.oreilly.com/radar/what-we-learned-...
# 3   https://www.oreilly.com/radar/the-collaborativ...
# 4   https://www.oreilly.com/radar/what-is-hyperaut...
# 5   https://www.oreilly.com/radar/radar-trends-to-...
# 6   https://www.oreilly.com/radar/the-problem-with...
# 7   https://www.oreilly.com/radar/radar-trends-to-...
# 8   https://www.oreilly.com/radar/ad-networks-and-...
# 9         https://www.oreilly.com/radar/on-technique/
# 10  https://www.oreilly.com/radar/scaling-false-pe...
# 11  https://www.oreilly.com/radar/the-metaverse-is...
# 12  https://www.oreilly.com/radar/radar-trends-to-...
# 13  https://www.oreilly.com/radar/sql-the-universa...
# 14  https://www.oreilly.com/radar/artificial-creat...
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/formal-informal-...
# 1   https://www.oreilly.com/radar/radar-trends-to-...
# 2   https://www.oreilly.com/radar/what-we-learned-...
# 3   https://www.oreilly.com/radar/the-collaborativ...
# 4   https://www.oreilly.com/radar/what-is-hyperaut...
# 5   https://www.oreilly.com/radar/radar-trends-to-...
# 6   https://www.oreilly.com/radar/the-problem-with...
# 7   https://www.oreilly.com/radar/radar-trends-to-...
# 8   https://www.oreilly.com/radar/ad-networks-and-...
# 9   https://www.oreilly.com/radar/on-technique/#re...
# 10  https://www.oreilly.com/radar/scaling-false-pe...
# 11  https://www.oreilly.com/radar/the-metaverse-is...
# 12  https://www.oreilly.com/radar/radar-trends-to-...
# 13  https://www.oreilly.com/radar/sql-the-universa...
# 14  https://www.oreilly.com/radar/artificial-creat...
#
#                           published                       published_parsed  \
# 0   Tue, 08 Nov 2022 11:58:09 +0000    (2022, 11, 8, 11, 58, 9, 1, 312, 0)
# 1   Tue, 01 Nov 2022 11:15:57 +0000   (2022, 11, 1, 11, 15, 57, 1, 305, 0)
# 2   Tue, 18 Oct 2022 11:14:23 +0000  (2022, 10, 18, 11, 14, 23, 1, 291, 0)
# 3   Wed, 12 Oct 2022 20:01:45 +0000   (2022, 10, 12, 20, 1, 45, 2, 285, 0)
# 4   Tue, 11 Oct 2022 10:59:21 +0000  (2022, 10, 11, 10, 59, 21, 1, 284, 0)
# 5   Tue, 04 Oct 2022 11:15:42 +0000   (2022, 10, 4, 11, 15, 42, 1, 277, 0)
# 6   Tue, 13 Sep 2022 11:21:40 +0000   (2022, 9, 13, 11, 21, 40, 1, 256, 0)
# 7   Tue, 06 Sep 2022 11:21:09 +0000     (2022, 9, 6, 11, 21, 9, 1, 249, 0)
# 8   Tue, 16 Aug 2022 11:21:21 +0000   (2022, 8, 16, 11, 21, 21, 1, 228, 0)
# 9   Tue, 09 Aug 2022 11:12:22 +0000    (2022, 8, 9, 11, 12, 22, 1, 221, 0)
# 10  Thu, 04 Aug 2022 11:12:44 +0000    (2022, 8, 4, 11, 12, 44, 3, 216, 0)
# 11  Tue, 02 Aug 2022 18:38:46 +0000    (2022, 8, 2, 18, 38, 46, 1, 214, 0)
# 12  Tue, 02 Aug 2022 11:18:24 +0000    (2022, 8, 2, 11, 18, 24, 1, 214, 0)
# 13  Tue, 19 Jul 2022 11:16:39 +0000   (2022, 7, 19, 11, 16, 39, 1, 200, 0)
# 14  Tue, 12 Jul 2022 13:24:16 +0000   (2022, 7, 12, 13, 24, 16, 1, 193, 0)
#
#                         authors         author              author_detail  \
# 0   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 1   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 2    [{'name': 'Patrick Hall'}]   Patrick Hall   {'name': 'Patrick Hall'}
# 3   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 4   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 5   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 6   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 7   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 8      [{'name': 'Q McCallum'}]     Q McCallum     {'name': 'Q McCallum'}
# 9   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 10  [{'name': 'Kevlin Henney'}]  Kevlin Henney  {'name': 'Kevlin Henney'}
# 11   [{'name': 'Tim O’Reilly'}]   Tim O’Reilly   {'name': 'Tim O’Reilly'}
# 12  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 13      [{'name': 'Jon Udell'}]      Jon Udell      {'name': 'Jon Udell'}
# 14  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
#
#                                                  tags  \
# 0   [{'term': 'Programming', 'scheme': None, 'labe...
# 1   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 2   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 3   [{'term': 'Metaverse', 'scheme': None, 'label'...
# 4   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 5   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 6   [{'term': 'Artificial Intelligence', 'scheme':...
# 7   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 8   [{'term': 'Operations', 'scheme': None, 'label...
# 9   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 10  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 11  [{'term': 'Metaverse', 'scheme': None, 'label'...
# 12  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 13  [{'term': 'Data', 'scheme': None, 'label': Non...
# 14  [{'term': 'Artificial Intelligence', 'scheme':...
#
#                                         id  guidislink  \
# 0   https://www.oreilly.com/radar/?p=14772       False
# 1   https://www.oreilly.com/radar/?p=14760       False
# 2   https://www.oreilly.com/radar/?p=14754       False
# 3   https://www.oreilly.com/radar/?p=14750       False
# 4   https://www.oreilly.com/radar/?p=14733       False
# 5   https://www.oreilly.com/radar/?p=14726       False
# 6   https://www.oreilly.com/radar/?p=14718       False
# 7   https://www.oreilly.com/radar/?p=14700       False
# 8   https://www.oreilly.com/radar/?p=14688       False
# 9   https://www.oreilly.com/radar/?p=14669       False
# 10  https://www.oreilly.com/radar/?p=14661       False
# 11  https://www.oreilly.com/radar/?p=14641       False
# 12  https://www.oreilly.com/radar/?p=14631       False
# 13  https://www.oreilly.com/radar/?p=14612       False
# 14  https://www.oreilly.com/radar/?p=14604       False
#
#                                               summary  \
# 0   We’ve all been impressed by the generative art...
# 1   Maintaining a separate category for AI is gett...
# 2   A recently passed law in New York City require...
# 3   We want to congratulate Dylan Field on his sta...
# 4   Gartner has anointed “Hyperautomation” one of ...
# 5   September was a busy month. In addition to con...
# 6   Projects like OpenAI’s DALL-E and DeepMind’s G...
# 7   It’s hardly news to talk about the AI developm...
# 8   In a recent Radar piece, I explored N-sided ma...
# 9   In a previous article, I wrote about how model...
# 10  Humans are notoriously poor at judging distanc...
# 11  The metaphors we use to describe new technolog...
# 12  The large model train keeps rolling on. This m...
# 13  Data scientists working in Python or R typical...
# 14  There’s a puzzling disconnect in the many arti...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments
# 0   https://www.oreilly.com/radar/formal-informal-...              0
# 1   https://www.oreilly.com/radar/radar-trends-to-...              0
# 2   https://www.oreilly.com/radar/what-we-learned-...              0
# 3   https://www.oreilly.com/radar/the-collaborativ...              0
# 4   https://www.oreilly.com/radar/what-is-hyperaut...              0
# 5   https://www.oreilly.com/radar/radar-trends-to-...              0
# 6   https://www.oreilly.com/radar/the-problem-with...              0
# 7   https://www.oreilly.com/radar/radar-trends-to-...              0
# 8   https://www.oreilly.com/radar/ad-networks-and-...              0
# 9    https://www.oreilly.com/radar/on-technique/feed/              0
# 10  https://www.oreilly.com/radar/scaling-false-pe...              0
# 11  https://www.oreilly.com/radar/the-metaverse-is...              0
# 12  https://www.oreilly.com/radar/radar-trends-to-...              0
# 13  https://www.oreilly.com/radar/sql-the-universa...              0
# 14  https://www.oreilly.com/radar/artificial-creat...              0

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df2 = df_entries.groupby(['author'])['author'].count()
df2.sort_values(ascending=False)
# Out:
# author
# Mike Loukides    10
# Jon Udell         1
# Kevlin Henney     1
# Patrick Hall      1
# Q McCallum        1
# Tim O’Reilly      1
# Name: author, dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
len_title = ([len(x) for x in titles])
len_title

df_entries['len_title'] = len_title

df_entries.sort_values('len_title', ascending=False)
# Out:
#                                                 title  \
# 2   What We Learned Auditing Sophisticated AI for ...
# 13           SQL: The Universal Solvent for REST APIs
# 7               Radar Trends to Watch: September 2022
# 1                Radar Trends to Watch: November 2022
# 5                 Radar Trends to Watch: October 2022
# 12                 Radar Trends to Watch: August 2022
# 8                   Ad Networks and Content Marketing
# 6                       The Problem with Intelligence
# 11                       The Metaverse Is Not a Place
# 3                         The Collaborative Metaverse
# 0                           Formal Informal Languages
# 4                            What Is Hyperautomation?
# 14                             Artificial Creativity?
# 10                                Scaling False Peaks
# 9                                        On Technique
#
#                                          title_detail  \
# 2   {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 0   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 2   https://www.oreilly.com/radar/what-we-learned-...
# 13  https://www.oreilly.com/radar/sql-the-universa...
# 7   https://www.oreilly.com/radar/radar-trends-to-...
# 1   https://www.oreilly.com/radar/radar-trends-to-...
# 5   https://www.oreilly.com/radar/radar-trends-to-...
# 12  https://www.oreilly.com/radar/radar-trends-to-...
# 8   https://www.oreilly.com/radar/ad-networks-and-...
# 6   https://www.oreilly.com/radar/the-problem-with...
# 11  https://www.oreilly.com/radar/the-metaverse-is...
# 3   https://www.oreilly.com/radar/the-collaborativ...
# 0   https://www.oreilly.com/radar/formal-informal-...
# 4   https://www.oreilly.com/radar/what-is-hyperaut...
# 14  https://www.oreilly.com/radar/artificial-creat...
# 10  https://www.oreilly.com/radar/scaling-false-pe...
# 9         https://www.oreilly.com/radar/on-technique/
#
#                                              comments  \
# 2   https://www.oreilly.com/radar/what-we-learned-...
# 13  https://www.oreilly.com/radar/sql-the-universa...
# 7   https://www.oreilly.com/radar/radar-trends-to-...
# 1   https://www.oreilly.com/radar/radar-trends-to-...
# 5   https://www.oreilly.com/radar/radar-trends-to-...
# 12  https://www.oreilly.com/radar/radar-trends-to-...
# 8   https://www.oreilly.com/radar/ad-networks-and-...
# 6   https://www.oreilly.com/radar/the-problem-with...
# 11  https://www.oreilly.com/radar/the-metaverse-is...
# 3   https://www.oreilly.com/radar/the-collaborativ...
# 0   https://www.oreilly.com/radar/formal-informal-...
# 4   https://www.oreilly.com/radar/what-is-hyperaut...
# 14  https://www.oreilly.com/radar/artificial-creat...
# 10  https://www.oreilly.com/radar/scaling-false-pe...
# 9   https://www.oreilly.com/radar/on-technique/#re...
#
#                           published                       published_parsed  \
# 2   Tue, 18 Oct 2022 11:14:23 +0000  (2022, 10, 18, 11, 14, 23, 1, 291, 0)
# 13  Tue, 19 Jul 2022 11:16:39 +0000   (2022, 7, 19, 11, 16, 39, 1, 200, 0)
# 7   Tue, 06 Sep 2022 11:21:09 +0000     (2022, 9, 6, 11, 21, 9, 1, 249, 0)
# 1   Tue, 01 Nov 2022 11:15:57 +0000   (2022, 11, 1, 11, 15, 57, 1, 305, 0)
# 5   Tue, 04 Oct 2022 11:15:42 +0000   (2022, 10, 4, 11, 15, 42, 1, 277, 0)
# 12  Tue, 02 Aug 2022 11:18:24 +0000    (2022, 8, 2, 11, 18, 24, 1, 214, 0)
# 8   Tue, 16 Aug 2022 11:21:21 +0000   (2022, 8, 16, 11, 21, 21, 1, 228, 0)
# 6   Tue, 13 Sep 2022 11:21:40 +0000   (2022, 9, 13, 11, 21, 40, 1, 256, 0)
# 11  Tue, 02 Aug 2022 18:38:46 +0000    (2022, 8, 2, 18, 38, 46, 1, 214, 0)
# 3   Wed, 12 Oct 2022 20:01:45 +0000   (2022, 10, 12, 20, 1, 45, 2, 285, 0)
# 0   Tue, 08 Nov 2022 11:58:09 +0000    (2022, 11, 8, 11, 58, 9, 1, 312, 0)
# 4   Tue, 11 Oct 2022 10:59:21 +0000  (2022, 10, 11, 10, 59, 21, 1, 284, 0)
# 14  Tue, 12 Jul 2022 13:24:16 +0000   (2022, 7, 12, 13, 24, 16, 1, 193, 0)
# 10  Thu, 04 Aug 2022 11:12:44 +0000    (2022, 8, 4, 11, 12, 44, 3, 216, 0)
# 9   Tue, 09 Aug 2022 11:12:22 +0000    (2022, 8, 9, 11, 12, 22, 1, 221, 0)
#
#                         authors         author              author_detail  \
# 2    [{'name': 'Patrick Hall'}]   Patrick Hall   {'name': 'Patrick Hall'}
# 13      [{'name': 'Jon Udell'}]      Jon Udell      {'name': 'Jon Udell'}
# 7   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 1   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 5   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 12  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 8      [{'name': 'Q McCallum'}]     Q McCallum     {'name': 'Q McCallum'}
# 6   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 11   [{'name': 'Tim O’Reilly'}]   Tim O’Reilly   {'name': 'Tim O’Reilly'}
# 3   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 0   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 4   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 14  [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
# 10  [{'name': 'Kevlin Henney'}]  Kevlin Henney  {'name': 'Kevlin Henney'}
# 9   [{'name': 'Mike Loukides'}]  Mike Loukides  {'name': 'Mike Loukides'}
#
#                                                  tags  \
# 2   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 13  [{'term': 'Data', 'scheme': None, 'label': Non...
# 7   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 1   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 5   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 12  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 8   [{'term': 'Operations', 'scheme': None, 'label...
# 6   [{'term': 'Artificial Intelligence', 'scheme':...
# 11  [{'term': 'Metaverse', 'scheme': None, 'label'...
# 3   [{'term': 'Metaverse', 'scheme': None, 'label'...
# 0   [{'term': 'Programming', 'scheme': None, 'labe...
# 4   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 14  [{'term': 'Artificial Intelligence', 'scheme':...
# 10  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 9   [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
#                                         id  guidislink  \
# 2   https://www.oreilly.com/radar/?p=14754       False
# 13  https://www.oreilly.com/radar/?p=14612       False
# 7   https://www.oreilly.com/radar/?p=14700       False
# 1   https://www.oreilly.com/radar/?p=14760       False
# 5   https://www.oreilly.com/radar/?p=14726       False
# 12  https://www.oreilly.com/radar/?p=14631       False
# 8   https://www.oreilly.com/radar/?p=14688       False
# 6   https://www.oreilly.com/radar/?p=14718       False
# 11  https://www.oreilly.com/radar/?p=14641       False
# 3   https://www.oreilly.com/radar/?p=14750       False
# 0   https://www.oreilly.com/radar/?p=14772       False
# 4   https://www.oreilly.com/radar/?p=14733       False
# 14  https://www.oreilly.com/radar/?p=14604       False
# 10  https://www.oreilly.com/radar/?p=14661       False
# 9   https://www.oreilly.com/radar/?p=14669       False
#
#                                               summary  \
# 2   A recently passed law in New York City require...
# 13  Data scientists working in Python or R typical...
# 7   It’s hardly news to talk about the AI developm...
# 1   Maintaining a separate category for AI is gett...
# 5   September was a busy month. In addition to con...
# 12  The large model train keeps rolling on. This m...
# 8   In a recent Radar piece, I explored N-sided ma...
# 6   Projects like OpenAI’s DALL-E and DeepMind’s G...
# 11  The metaphors we use to describe new technolog...
# 3   We want to congratulate Dylan Field on his sta...
# 0   We’ve all been impressed by the generative art...
# 4   Gartner has anointed “Hyperautomation” one of ...
# 14  There’s a puzzling disconnect in the many arti...
# 10  Humans are notoriously poor at judging distanc...
# 9   In a previous article, I wrote about how model...
#
#                                        summary_detail  \
# 2   {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 0   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 2   [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 0   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments  \
# 2   https://www.oreilly.com/radar/what-we-learned-...              0
# 13  https://www.oreilly.com/radar/sql-the-universa...              0
# 7   https://www.oreilly.com/radar/radar-trends-to-...              0
# 1   https://www.oreilly.com/radar/radar-trends-to-...              0
# 5   https://www.oreilly.com/radar/radar-trends-to-...              0
# 12  https://www.oreilly.com/radar/radar-trends-to-...              0
# 8   https://www.oreilly.com/radar/ad-networks-and-...              0
# 6   https://www.oreilly.com/radar/the-problem-with...              0
# 11  https://www.oreilly.com/radar/the-metaverse-is...              0
# 3   https://www.oreilly.com/radar/the-collaborativ...              0
# 0   https://www.oreilly.com/radar/formal-informal-...              0
# 4   https://www.oreilly.com/radar/what-is-hyperaut...              0
# 14  https://www.oreilly.com/radar/artificial-creat...              0
# 10  https://www.oreilly.com/radar/scaling-false-pe...              0
# 9    https://www.oreilly.com/radar/on-technique/feed/              0
#
#     len_title
# 2          50
# 13         40
# 7          37
# 1          36
# 5          35
# 12         34
# 8          33
# 6          29
# 11         28
# 3          27
# 0          25
# 4          24
# 14         22
# 10         19
# 9          12

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
[x['title'] for x in doc['entries'] if 'machine learning' in x['summary']]
# Out:
# ['Radar Trends to Watch: October 2022']
